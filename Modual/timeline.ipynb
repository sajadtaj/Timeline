# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import plotly.express as px

import os
os.chdir(r'H:\python\Time line Project')
import plotly

# %%
data = pd.read_pickle(rf'Data\CleanData.csv')
data
# Out:
#             Date    Open    High     Low   Close  Volume Currency     Time  \
# 4778  2019-01-02  1285.0  1291.0  1280.6  1284.1  235334      USD      NaN
# 4779  2019-01-03  1290.4  1296.9  1286.4  1294.8  244542      USD  8:15:00
# 4780  2019-01-04  1298.9  1300.0  1278.1  1285.8  316063      USD  8:30:00
# 4781  2019-01-07  1290.2  1297.0  1287.3  1289.9  204679      USD      NaN
# 4782  2019-01-08  1287.4  1288.4  1280.2  1285.9  221915      USD      NaN
# ...          ...     ...     ...     ...     ...     ...      ...      ...
# 5353  2021-04-16  1764.8  1784.7  1760.3  1780.2  173498      USD  8:30:00
# 5354  2021-04-19  1778.8  1790.4  1766.6  1770.6  180726      USD      NaN
# 5355  2021-04-20  1770.5  1780.8  1763.5  1778.4  169041      USD      NaN
# 5356  2021-04-21  1779.1  1798.4  1776.6  1793.1  173968      USD      NaN
# 5357  2021-04-22  1794.5  1798.1  1777.1  1782.0  163753      USD  8:30:00
#
# ...

# %%
data.head(5)
# Out:
#             Date    Open    High     Low   Close  Volume Currency     Time  \
# 4778  2019-01-02  1285.0  1291.0  1280.6  1284.1  235334      USD      NaN
# 4779  2019-01-03  1290.4  1296.9  1286.4  1294.8  244542      USD  8:15:00
# 4780  2019-01-04  1298.9  1300.0  1278.1  1285.8  316063      USD  8:30:00
# 4781  2019-01-07  1290.2  1297.0  1287.3  1289.9  204679      USD      NaN
# 4782  2019-01-08  1287.4  1288.4  1280.2  1285.9  221915      USD      NaN
#
#                                country                        Volatility  \
# 4778                               NaN                               NaN
# 4779  United States                     High Volatility Expected
# 4780  United States                     High Volatility Expected
# 4781                               NaN                               NaN
# 4782                               NaN                               NaN
#
#                                             Description  \
# ...

# %%
import plotly.express as px

fig = px.line(data, x="Date", y="Close", title='Gold Price',text   ='Description')
fig.show()

# %%
df = pd.DataFrame({
    'x': [1, 2, 3, 4, 5],
    'y': [1, 4, 9, 16, 25]
})

fig = px.line(df, x='x', y='y')
fig.add_vline(x =3)
# fig.update_layout(
#     shapes=[
#         dict(
#             type='line',
#             x0=3,
#             y0=1,
#             x1=3,
#             y1=1,
#             yref='paper',
#             line=dict(
#                 color='red',
#                 width=2
#             )
#         )
#     ]
# )

# fig.add_vrect(x0=1.9, x1=2,)



fig.add_hline(y=1, line_dash="dot",
              annotation_text="Jan 1, 2018 baseline", 
              annotation_position="bottom right",col=2)

fig.add_vrect(x0=3, x1=4, 
              annotation_text="decline", annotation_position="top left",
              fillcolor="green", opacity=0.25, line_width=0)
fig.show()
